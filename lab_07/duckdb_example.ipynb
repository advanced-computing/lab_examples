# %%
import pandas as pd
import duckdb

# %%
with duckdb.connect('world_bank.db') as con:
    df = con.table('electricity').to_df()
    print(df)
# Out:
#                                           Series Name     Series Code  \
# 0             Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 1             Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 2             Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 3             Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 4             Access to electricity (% of population)  EG.ELC.ACCS.ZS
# ..                                                ...             ...
# 266                                              None            None
# 267                                              None            None
# 268                                              None            None
# 269  Data from database: World Development Indicators            None
# 270                          Last Updated: 01/28/2025            None
#
#        Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2014 [YR2014]  \
# 0       Afghanistan          AFG            ..           4.4          89.5
# 1           Albania          ALB           100          99.4           100
# 2           Algeria          DZA            ..          98.6          99.3
# 3    American Samoa          ASM            ..            ..            ..
# 4           Andorra          AND           100           100           100
# ..              ...          ...           ...           ...           ...
# 266            None         None          None          None          None
# 267            None         None          None          None          None
# 268            None         None          None          None          None
# 269            None         None          None          None          None
# 270            None         None          None          None          None
#
#     2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019]  \
# 0            71.5          97.7          97.7          93.4          97.7
# 1             100          99.9          99.9           100           100
# 2            99.4          99.4          99.5          99.6          99.5
# 3              ..            ..            ..            ..            ..
# 4             100           100           100           100           100
# ..            ...           ...           ...           ...           ...
# 266          None          None          None          None          None
# 267          None          None          None          None          None
# 268          None          None          None          None          None
# 269          None          None          None          None          None
# 270          None          None          None          None          None
#
#     2020 [YR2020] 2021 [YR2021] 2022 [YR2022] 2023 [YR2023]
# 0            97.7          97.7          85.3            ..
# 1             100           100           100            ..
# 2            99.7          99.8           100            ..
# 3              ..            ..            ..            ..
# 4             100           100           100            ..
# ..            ...           ...           ...           ...
# 266          None          None          None          None
# 267          None          None          None          None
# 268          None          None          None          None
# 269          None          None          None          None
# 270          None          None          None          None
#
# [271 rows x 16 columns]

# %%
df.head()
# Out:
#                                Series Name     Series Code    Country Name  \
# 0  Access to electricity (% of population)  EG.ELC.ACCS.ZS     Afghanistan
# 1  Access to electricity (% of population)  EG.ELC.ACCS.ZS         Albania
# 2  Access to electricity (% of population)  EG.ELC.ACCS.ZS         Algeria
# 3  Access to electricity (% of population)  EG.ELC.ACCS.ZS  American Samoa
# 4  Access to electricity (% of population)  EG.ELC.ACCS.ZS         Andorra
#
#   Country Code 1990 [YR1990] 2000 [YR2000] 2014 [YR2014] 2015 [YR2015]  \
# 0          AFG            ..           4.4          89.5          71.5
# 1          ALB           100          99.4           100           100
# 2          DZA            ..          98.6          99.3          99.4
# 3          ASM            ..            ..            ..            ..
# 4          AND           100           100           100           100
#
#   2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019] 2020 [YR2020]  \
# 0          97.7          97.7          93.4          97.7          97.7
# 1          99.9          99.9           100           100           100
# 2          99.4          99.5          99.6          99.5          99.7
# 3            ..            ..            ..            ..            ..
# 4           100           100           100           100           100
#
#   2021 [YR2021] 2022 [YR2022] 2023 [YR2023]
# 0          97.7          85.3            ..
# 1           100           100            ..
# 2          99.8           100            ..
# 3            ..            ..            ..
# 4           100           100            ..

# %%
# create a connection to the world_bank.db
con = duckdb.connect('world_bank.db')

# show all tables in the database
print(con.execute("SHOW TABLES").fetchall())
# Out:
# [('electricity',)]

# %%
# create a connection to the world_bank.db
con2 = duckdb.connect('world_bank.db')

# show all tables in the database
print(con2.execute("SHOW TABLES").fetchall())
# Out:
# [('electricity',)]

# %%
con.table('electricity').show()
# Out:
# ┌──────────────────────────────────────────────────┬────────────────┬────────────────────────────────────────────┬──────────────┬──────────────────┬──────────────────┬──────────────────┬──────────────────┬──────────────────┬──────────────────┬──────────────────┬──────────────────┬──────────────────┬──────────────────┬──────────────────┬───────────────┐
# │                   Series Name                    │  Series Code   │                Country Name                │ Country Code │  1990 [YR1990]   │  2000 [YR2000]   │  2014 [YR2014]   │  2015 [YR2015]   │  2016 [YR2016]   │  2017 [YR2017]   │  2018 [YR2018]   │  2019 [YR2019]   │  2020 [YR2020]   │  2021 [YR2021]   │  2022 [YR2022]   │ 2023 [YR2023] │
# │                     varchar                      │    varchar     │                  varchar                   │   varchar    │     varchar      │     varchar      │     varchar      │     varchar      │     varchar      │     varchar      │     varchar      │     varchar      │     varchar      │     varchar      │     varchar      │    varchar    │
# ├──────────────────────────────────────────────────┼────────────────┼────────────────────────────────────────────┼──────────────┼──────────────────┼──────────────────┼──────────────────┼──────────────────┼──────────────────┼──────────────────┼──────────────────┼──────────────────┼──────────────────┼──────────────────┼──────────────────┼───────────────┤
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ Afghanistan                                │ AFG          │ ..               │ 4.4              │ 89.5             │ 71.5             │ 97.7             │ 97.7             │ 93.4             │ 97.7             │ 97.7             │ 97.7             │ 85.3             │ ..            │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ Albania                                    │ ALB          │ 100              │ 99.4             │ 100              │ 100              │ 99.9             │ 99.9             │ 100              │ 100              │ 100              │ 100              │ 100              │ ..            │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ Algeria                                    │ DZA          │ ..               │ 98.6             │ 99.3             │ 99.4             │ 99.4             │ 99.5             │ 99.6             │ 99.5             │ 99.7             │ 99.8             │ 100              │ ..            │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ American Samoa                             │ ASM          │ ..               │ ..               │ ..               │ ..               │ ..               │ ..               │ ..               │ ..               │ ..               │ ..               │ ..               │ ..            │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ Andorra                                    │ AND          │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ ..            │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ Angola                                     │ AGO          │ ..               │ 24.2             │ 32               │ 42               │ 41.8             │ 42.9             │ 45.3             │ 45.6             │ 47               │ 48.2             │ 48.5             │ ..            │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ Antigua and Barbuda                        │ ATG          │ 95.7630462646484 │ 97.7             │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ ..            │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ Argentina                                  │ ARG          │ 92.1548004150391 │ 95.7             │ 100              │ 99.7             │ 99.9             │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ ..            │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ Armenia                                    │ ARM          │ ..               │ 98.9             │ 99.7             │ 100              │ 99.8             │ 99.7             │ 99.9             │ 100              │ 100              │ 100              │ 100              │ ..            │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ Aruba                                      │ ABW          │ 100              │ 91.7             │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ 100              │ 99.9             │ ..            │
# │                    ·                             │       ·        │   ·                                        │  ·           │ ·                │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │ ·             │
# │                    ·                             │       ·        │   ·                                        │  ·           │ ·                │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │ ·             │
# │                    ·                             │       ·        │   ·                                        │  ·           │ ·                │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │  ·               │ ·             │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ Sub-Saharan Africa                         │ SSF          │ ..               │ 25.700773726639  │ 38.3544769303453 │ 39.1996500160838 │ 43.8301651403807 │ 43.7628194566177 │ 46.4166752425457 │ 47.1974168154517 │ 48.5450389491045 │ 50.6566448640617 │ 51.512559668342  │ ..            │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ Sub-Saharan Africa (excluding high income) │ SSA          │ ..               │ 25.6925016730781 │ 38.348833033686  │ 39.1941094949299 │ 43.8251135182673 │ 43.7578326767506 │ 46.4120038049762 │ 47.1928919113376 │ 48.5407047162867 │ 50.6525597268546 │ 51.5078304918426 │ ..            │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ Sub-Saharan Africa (IDA & IBRD countries)  │ TSS          │ ..               │ 25.700773726639  │ 38.3544769303453 │ 39.1996500160838 │ 43.8301651403807 │ 43.7628194566177 │ 46.4166752425457 │ 47.1974168154518 │ 48.5450389491045 │ 50.6566448640617 │ 51.512559668342  │ ..            │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ Upper middle income                        │ UMC          │ ..               │ 94.3273600863386 │ 98.8783432928367 │ 98.9597889342189 │ 98.99324246416   │ 99.1210835166054 │ 99.1384189571732 │ 99.2355189253177 │ 99.1739709844954 │ 99.3931573305582 │ 99.4658003895695 │ ..            │
# │ Access to electricity (% of population)          │ EG.ELC.ACCS.ZS │ World                                      │ WLD          │ ..               │ 78.2214009100849 │ 86.1952045782154 │ 86.923548113864  │ 88.1038273506242 │ 88.9310968401293 │ 89.7963518726606 │ 90.1069300693474 │ 90.3973782618433 │ 91.3349919924229 │ 91.277853325244  │ ..            │
# │ NULL                                             │ NULL           │ NULL                                       │ NULL         │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL          │
# │ NULL                                             │ NULL           │ NULL                                       │ NULL         │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL          │
# │ NULL                                             │ NULL           │ NULL                                       │ NULL         │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL          │
# │ Data from database: World Development Indicators │ NULL           │ NULL                                       │ NULL         │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL          │
# │ Last Updated: 01/28/2025                         │ NULL           │ NULL                                       │ NULL         │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL             │ NULL          │
# ├──────────────────────────────────────────────────┴────────────────┴────────────────────────────────────────────┴──────────────┴──────────────────┴──────────────────┴──────────────────┴──────────────────┴──────────────────┴──────────────────┴──────────────────┴──────────────────┴──────────────────┴──────────────────┴──────────────────┴───────────────┤
# │ 271 rows (20 shown)                                                                                                                                                                                                                                                                                                                                 16 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# to pandas
df = con.table('electricity').to_df()
df.head()
# Out:
#                                Series Name     Series Code    Country Name  \
# 0  Access to electricity (% of population)  EG.ELC.ACCS.ZS     Afghanistan
# 1  Access to electricity (% of population)  EG.ELC.ACCS.ZS         Albania
# 2  Access to electricity (% of population)  EG.ELC.ACCS.ZS         Algeria
# 3  Access to electricity (% of population)  EG.ELC.ACCS.ZS  American Samoa
# 4  Access to electricity (% of population)  EG.ELC.ACCS.ZS         Andorra
#
#   Country Code 1990 [YR1990] 2000 [YR2000] 2014 [YR2014] 2015 [YR2015]  \
# 0          AFG            ..           4.4          89.5          71.5
# 1          ALB           100          99.4           100           100
# 2          DZA            ..          98.6          99.3          99.4
# 3          ASM            ..            ..            ..            ..
# 4          AND           100           100           100           100
#
#   2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019] 2020 [YR2020]  \
# 0          97.7          97.7          93.4          97.7          97.7
# 1          99.9          99.9           100           100           100
# 2          99.4          99.5          99.6          99.5          99.7
# 3            ..            ..            ..            ..            ..
# 4           100           100           100           100           100
#
#   2021 [YR2021] 2022 [YR2022] 2023 [YR2023]
# 0          97.7          85.3            ..
# 1           100           100            ..
# 2          99.8           100            ..
# 3            ..            ..            ..
# 4           100           100            ..

# %%
con.close()
